# %%
import pandas as pd

# %%
vik = pd.read_csv("C:/Users/Lenovo/Dropbox/PC/Downloads/FIFA22_official_data.csv")

# %%
vik
# Out:
#            ID             Name  Age Nationality  \
# 0      212198  Bruno Fernandes   26    Portugal
# 1      209658      L. Goretzka   26     Germany
# 2      176580        L. Suárez   34     Uruguay
# 3      192985     K. De Bruyne   30     Belgium
# 4      224334         M. Acuña   29   Argentina
# ...       ...              ...  ...         ...
# 16705  240558    18 L. Clayton   17     England
# 16706  262846         �. Dobre   20     Romania
# 16707  241317   21 Xue Qinghao   19    China PR
# 16708  259646        A. Shaikh   18       India
# 16709  178453    07 A. Censori   17       Italy
#
#                                           Flag  Overall  Potential  \
# 0          https://cdn.sofifa.com/flags/pt.png       88         89
# 1          https://cdn.sofifa.com/flags/de.png       87         88
# 2          https://cdn.sofifa.com/flags/uy.png       88         88
# 3          https://cdn.sofifa.com/flags/be.png       91         91
# ...

# %%
vik.describe()
# Out:
#                   ID           Age       Overall     Potential       Special  \
# count   16710.000000  16710.000000  16710.000000  16710.000000  16710.000000
# mean   220560.467923     25.727409     67.646320     72.572292   1652.497307
# std     38496.607959      5.048910      6.457695      5.688085    257.271696
# min        27.000000     16.000000     28.000000     38.000000    571.000000
# 25%    203891.250000     22.000000     63.000000     69.000000   1525.000000
# 50%    229253.000000     25.000000     68.000000     72.000000   1687.000000
# 75%    245368.750000     29.000000     72.000000     76.000000   1826.000000
# max    264704.000000     54.000000     93.000000     95.000000   2341.000000
#
#        International Reputation     Weak Foot   Skill Moves  Jersey Number  \
# count              16710.000000  16710.000000  16710.000000   16684.000000
# mean                   1.169958      3.008199      2.475464      20.458643
# ...

# %%
vik.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16710 entries, 0 to 16709
# Data columns (total 63 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        16710 non-null  int64
#  1   Name                      16710 non-null  object
#  2   Age                       16710 non-null  int64
#  3   Nationality               16710 non-null  object
#  4   Flag                      16710 non-null  object
#  5   Overall                   16710 non-null  int64
#  6   Potential                 16710 non-null  int64
#  7   Club                      16446 non-null  object
#  8   Value                     16710 non-null  object
#  9   Wage                      16710 non-null  object
#  10  Special                   16710 non-null  int64
#  11  Preferred Foot            16710 non-null  object
#  12  International Reputation  16710 non-null  int64
# ...

# %%
vik.isna()
# Out:
#           ID   Name    Age  Nationality   Flag  Overall  Potential   Club  \
# 0      False  False  False        False  False    False      False  False
# 1      False  False  False        False  False    False      False  False
# 2      False  False  False        False  False    False      False  False
# 3      False  False  False        False  False    False      False  False
# 4      False  False  False        False  False    False      False  False
# ...      ...    ...    ...          ...    ...      ...        ...    ...
# 16705  False  False  False        False  False    False      False  False
# 16706  False  False  False        False  False    False      False  False
# 16707  False  False  False        False  False    False      False  False
# 16708  False  False  False        False  False    False      False  False
# 16709  False  False  False        False  False    False      False  False
#
#        Value   Wage  ...  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# ...

# %%
vik.isna().count().sum()
# Out:
# 1052730

# %%
vik.count().sum()
# Out:
# 1015930

# %%
vik.plot()
# Out:
# <Axes: >

# %%
vik.plot(kind="bar",x="Age",y="ShotPower")
# Out:
# <Axes: xlabel='Age'>

# %%
vik["Age"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
vik['Overall'].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib as mat
