# %%
import seaborn as sns
import pandas as pd

# %%
vik = sns.load_dataset("tips")

# %%
vik
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
drivers = pd.read_csv("driver_standings.csv")

# %%
drivers
# Out:
#        driverStandingsId  raceId  driverId  points  position positionText  \
# 0                      1      18         1    10.0         1            1
# 1                      2      18         2     8.0         2            2
# 2                      3      18         3     6.0         3            3
# 3                      4      18         4     5.0         4            4
# 4                      5      18         5     4.0         5            5
# ...                  ...     ...       ...     ...       ...          ...
# 33201              70567    1064       842    66.0         8            8
# 33202              70568    1064       849     7.0        16           16
# 33203              70569    1064         4    46.0        10           10
# 33204              70570    1064       853     0.0        20           20
# 33205              70571    1064         9     0.0        21           21
#
#        wins
# 0         1
# 1         0
# 2         0
# 3         0
# ...

# %%
sns.scatterplot(drivers,x="raceId",y="driverId",hue="position")
# Out:
# <Axes: xlabel='raceId', ylabel='driverId'>

# %%
sns.barplot(drivers,x="position",y="wins")
# Out:
# <Axes: xlabel='position', ylabel='wins'>

# %%
drivers
# Out:
#        driverStandingsId  raceId  driverId  points  position positionText  \
# 0                      1      18         1    10.0         1            1
# 1                      2      18         2     8.0         2            2
# 2                      3      18         3     6.0         3            3
# 3                      4      18         4     5.0         4            4
# 4                      5      18         5     4.0         5            5
# ...                  ...     ...       ...     ...       ...          ...
# 33201              70567    1064       842    66.0         8            8
# 33202              70568    1064       849     7.0        16           16
# 33203              70569    1064         4    46.0        10           10
# 33204              70570    1064       853     0.0        20           20
# 33205              70571    1064         9     0.0        21           21
#
#        wins
# 0         1
# 1         0
# 2         0
# 3         0
# ...

# %%
drive = drivers[0:50]

# %%
drive
# Out:
#     driverStandingsId  raceId  driverId  points  position positionText  wins
# 0                   1      18         1    10.0         1            1     1
# 1                   2      18         2     8.0         2            2     0
# 2                   3      18         3     6.0         3            3     0
# 3                   4      18         4     5.0         4            4     0
# 4                   5      18         5     4.0         5            5     0
# 5                   6      18         6     3.0         6            6     0
# 6                   7      18         7     2.0         7            7     0
# 7                   8      18         8     1.0         8            8     0
# 8                   9      19         1    14.0         1            1     1
# 9                  10      19         2    11.0         3            3     0
# 10                 11      19         3     6.0         6            6     0
# ...

# %%
sns.barplot(drive,x="raceId",y="wins")
# Out:
# <Axes: xlabel='raceId', ylabel='wins'>

# %%
sns.scatterplot(drive,x="points",y="points")
# Out:
# <Axes: xlabel='points', ylabel='points'>
