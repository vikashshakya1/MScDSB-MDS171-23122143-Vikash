# %%
# Load a csv, set a new col names
#Rename column names(1 column,multiple column)
# Load a dataset, set one column as inndex column
# split your data into multiple file with respect to rows columns 
# Load the different files and merge them to final file

# %%
import pandas as pd

task = pd.read_csv("C:/Users/Lenovo/.jupyter/Python Classes/Movies.csv")

# %%
task
# Out:
#       Unnamed: 0 release_date                             movie  \
# 0              1    6/22/2007                     Evan Almighty
# 1              2    7/28/1995                        Waterworld
# 2              3   05-12-2017  King Arthur: Legend of the Sword
# 3              4   12/25/2013                          47 Ronin
# 4              5    6/22/2018    Jurassic World: Fallen Kingdom
# ...          ...          ...                               ...
# 3396        3397   10/28/2011                        Like Crazy
# 3397        3398    7/14/2000                        Chuck&Buck
# 3398        3399    3/28/1997       Love and Other Catastrophes
# 3399        3400    8/28/1998        I Married a Strange Person
# 3400        3401    7/22/2005                          November
#
#       production_budget  domestic_gross  worldwide_gross  \
# 0           175000000.0     100289690.0     1.741313e+08
# 1           175000000.0      88246220.0     2.642462e+08
# ...

# %%
movie =task[0:30]

# %%
movie
# Out:
#     Unnamed: 0 release_date                                movie  \
# 0            1    6/22/2007                        Evan Almighty
# 1            2    7/28/1995                           Waterworld
# 2            3   05-12-2017     King Arthur: Legend of the Sword
# 3            4   12/25/2013                             47 Ronin
# 4            5    6/22/2018       Jurassic World: Fallen Kingdom
# 5            6   08-01-2014              Guardians of the Galaxy
# 6            7   05-07-2010                           Iron Man 2
# 7            8   04-04-2014  Captain America: The Winter Soldier
# 8            9   07-11-2014       Dawn of the Planet of the Apes
# 9           10   11-10-2004                    The Polar Express
# 10          11   06-01-2012          Snow White and the Huntsman
# 11          12   07-01-2003   Terminator 3: Rise of the Machines
# 12          13   05-07-2004                          Van Helsing
# ...

# %%
movie.rename(columns={"Unnamed: 0":"Sr. No.","movie":"MOVIES","production_budget":"Production Budget","domestic_gross":"Domestic_Gross","mpaa_rating":"Mappa_Rating"})
# Out:
#     Sr. No. release_date                               MOVIES  \
# 0         1    6/22/2007                        Evan Almighty
# 1         2    7/28/1995                           Waterworld
# 2         3   05-12-2017     King Arthur: Legend of the Sword
# 3         4   12/25/2013                             47 Ronin
# 4         5    6/22/2018       Jurassic World: Fallen Kingdom
# 5         6   08-01-2014              Guardians of the Galaxy
# 6         7   05-07-2010                           Iron Man 2
# 7         8   04-04-2014  Captain America: The Winter Soldier
# 8         9   07-11-2014       Dawn of the Planet of the Apes
# 9        10   11-10-2004                    The Polar Express
# 10       11   06-01-2012          Snow White and the Huntsman
# 11       12   07-01-2003   Terminator 3: Rise of the Machines
# 12       13   05-07-2004                          Van Helsing
# 13       14    5/22/2015                         Tomorrowland
# ...

# %%
bakchodi = pd.read_csv("C:/Users/Lenovo/.jupyter/Python Classes/Bakchdoi.csv")

# %%
bakchodi
# Out:
#    Roll No.      Names  Marks
# 0         1  Swasdickk   -100
# 1         2  Swasdickk   -100
# 2         3  Swasdickk   -100
# 3         4  Swasdickk   -100
# 4         5  Swasdickk   -100

# %%
bakchodi.set_index('Names')
# Out:
#            Roll No.  Marks
# Names
# Swasdickk         1   -100
# Swasdickk         2   -100
# Swasdickk         3   -100
# Swasdickk         4   -100
# Swasdickk         5   -100

# %%
df1 = bakchodi.iloc[:2,:]
df2 = bakchodi.iloc[2:,:]
print(df1)
print("---------------------------")
print(df2)
# Out:
#    Roll No.      Names  Marks
# 0         1  Swasdickk   -100
# 1         2  Swasdickk   -100
# ---------------------------
#    Roll No.      Names  Marks
# 2         3  Swasdickk   -100
# 3         4  Swasdickk   -100
# 4         5  Swasdickk   -100

# %%
df1 = bakchodi.iloc[:,:2]
df2 = bakchodi.iloc[:,2:]
print(df1)
print("---------------------------")
print(df2)
# Out:
#    Roll No.      Names
# 0         1  Swasdickk
# 1         2  Swasdickk
# 2         3  Swasdickk
# 3         4  Swasdickk
# 4         5  Swasdickk
# ---------------------------
#    Marks
# 0   -100
# 1   -100
# 2   -100
# 3   -100
# 4   -100

# %%
bakchodi
# Out:
#    Roll No.      Names  Marks
# 0         1  Swasdickk   -100
# 1         2  Swasdickk   -100
# 2         3  Swasdickk   -100
# 3         4  Swasdickk   -100
# 4         5  Swasdickk   -100

# %%
movie =task.iloc[0:3,0:3]
movie1=task.iloc[2:6,0:3]

# %%
movie1
# Out:
#    Unnamed: 0 release_date                             movie
# 2           3   05-12-2017  King Arthur: Legend of the Sword
# 3           4   12/25/2013                          47 Ronin
# 4           5    6/22/2018    Jurassic World: Fallen Kingdom
# 5           6   08-01-2014           Guardians of the Galaxy

# %%
movie
# Out:
#    Unnamed: 0 release_date                             movie
# 0           1    6/22/2007                     Evan Almighty
# 1           2    7/28/1995                        Waterworld
# 2           3   05-12-2017  King Arthur: Legend of the Sword

# %%
pd.merge(movie,movie1,how="outer")
# Out:
#    Unnamed: 0 release_date                             movie
# 0           1    6/22/2007                     Evan Almighty
# 1           2    7/28/1995                        Waterworld
# 2           3   05-12-2017  King Arthur: Legend of the Sword
# 3           4   12/25/2013                          47 Ronin
# 4           5    6/22/2018    Jurassic World: Fallen Kingdom
# 5           6   08-01-2014           Guardians of the Galaxy
